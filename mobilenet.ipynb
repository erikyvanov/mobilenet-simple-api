# %%
import numpy as np
import tensorflow as tf
from IPython.display import Image
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications import imagenet_utils

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Num GPUs Available:  1

# %%
mobilenet = tf.keras.applications.mobilenet_v2.MobileNetV2()

# %%
def prepare_image(file):
    img = image.load_img(file, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array_expanded_dims = np.expand_dims(img_array, axis=0)
    return tf.keras.applications.mobilenet_v2.preprocess_input(img_array_expanded_dims)

# %%
image_path = 'platano.jpg'

# %%
Image(filename=image_path, width=300,height=200)

# %%
preprocessed_image = prepare_image(image_path)
predictions = mobilenet.predict(preprocessed_image)

# %%
results = imagenet_utils.decode_predictions(predictions)

# %%
results
# Out:
# [[('n07753592', 'banana', 0.8608244),
#   ('n07716358', 'zucchini', 0.009250291),
#   ('n07716906', 'spaghetti_squash', 0.008842916),
#   ('n07717556', 'butternut_squash', 0.0046755187),
#   ('n07754684', 'jackfruit', 0.002226923)]]
